# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = [10,5]

import warnings

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
current_palette1 = sns.color_palette()

sns.palplot(current_palette1)

plt.show()

# %%
current_palette2 = sns.color_palette()

sns.palplot(sns.color_palette("Reds"))

plt.show()

# %%
current_palette3 = sns.color_palette()

sns.palplot(sns.color_palette("BrBG", 20))

plt.show()

# %%
current_palette4 = sns.color_palette()

sns.palplot(sns.color_palette("colorblind"))

plt.show()

# %%
full_data = pd.read_csv("titanic_dataset.csv")

# %%
full_data.shape
# Out:
# (891, 12)

# %%
full_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.histplot(full_data['Parch'], kde = False)
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.distplot(full_data["Age"], hist = False)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.distplot(full_data['Age'])
plt.show()

# %%
sns.relplot(x = "Age", y = "Fare", col = "Pclass", hue = "Sex", kind = "line", data = full_data)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.scatterplot(x = "Age", y = "Fare", hue = "Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.lineplot(x = "Age", y = "Fare", hue = "Sex", style = "Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.barplot(x = "Sex", y = "Survived", hue = "Pclass", data = full_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 plt.figure(figsize = (8,8))
# ----> 2 sns.barplot(x = "Sex", y = "Survived", hue = "Pclass", data = full_data)
#       3 plt.show()
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\matplotlib\axes\_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\matplotlib\legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\matplotlib\legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %%
plt.figure(figsize = (8,8))
sns.stripplot(x = "Sex", y = "Age", hue = "Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.swarmplot(x = "Sex", y = "Age", hue = "Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.boxplot(x = "Survived", y ="Age", data = full_data)
plt.show()

# %%
sns.violinplot(x = "Survived", y ="Age", hue = "Sex", data = full_data)
plt.show()

# %%
sns.countplot(x = "Survived", data = full_data, palette = "Blues")
plt.show()

# %%
plt.subplots(figsize = (8,8))
sns.pointplot(x = "Sex", y = "Survived", hue = "Pclass", data = full_data)
plt.show()

# %%
sns.lmplot(x = "Age", y = "Fare", data = full_data)
plt.show()

# %%
plt.subplots(figsize = (10,10))
sns.regplot(x = "Age", y ="Fare", data = full_data)
plt.show()

# %%
plt.subplots(figsize = (10,10))
sns.regplot(x = "Fare", y ="Fare", data = full_data)
plt.show()

# %%
plt.subplots(figsize = (10,10))
sns.heatmap(full_data.corr(), cmap = "YlGnBu", annot = True, fmt = ".2f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.subplots(figsize = (10,10))
# ----> 2 sns.heatmap(full_data.corr(), cmap = "YlGnBu", annot = True, fmt = ".2f")
#       3 plt.show()
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\.anaconda\anaconda 2024\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Braund, Mr. Owen Harris'

# %%
g = sns.FacetGrid(full_data, col = "Survived", row = "Pclass")

g.map(plt.hist, "Age")
g.add_legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = [10,5]
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.heatmap(full_data.isnull(), yticklabels = False, cbar = False, cmap = "tab20c_r")
plt.title("Missing Values: Training Set")
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = "Pclass", y = "Age", data = full_data, palette = "GnBu_d").set_title("Age by Passenger Class")
plt.show()

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]

    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

full_data["Age"] = full_data[["Age", "Pclass"]].apply(impute_age, axis = 1)

# %%
full_data.drop("Cabin", axis = 1, inplace = True)

# %%
full_data.dropna(inplace = True)

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [889 rows x 11 columns]

# %%
full_data.drop(["Name", "Ticket"], axis = 1, inplace = True)

objcat = ["Sex", "Embarked"]

for colname in objcat:
    full_data[colname] = full_data[colname].astype("category")

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  24.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [889 rows x 9 columns]

# %%
full_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.019314    0.524184
# std     256.998173    0.486260    0.834700   13.209814    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.000000    1.000000    3.000000   36.500000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
full_data.drop("PassengerId", inplace = True, axis = 1)

# %%
full_data.shape
# Out:
# (889, 8)

# %%
full_data.select_dtypes(["category"]).columns
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
sex = pd.get_dummies(full_data["Sex"], drop_first = True)
embarked = pd.get_dummies(full_data["Embarked"], drop_first = True)

# %%
full_data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
full_data = pd.concat([full_data, sex, embarked], axis = 1)
full_data.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked   male  \
# 0         0       3    male  22.0      1      0   7.2500        S   True
# 1         1       1  female  38.0      1      0  71.2833        C  False
# 2         1       3  female  26.0      0      0   7.9250        S  False
# 3         1       1  female  35.0      1      0  53.1000        S  False
# 4         0       3    male  35.0      0      0   8.0500        S   True
#
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
full_data.drop(["Sex", "Embarked"], axis = 1, inplace = True)
print("train_data shape:", full_data.shape)
full_data.head()
# Out:
# train_data shape: (889, 9)
#    Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0         0       3  22.0      1      0   7.2500   True  False   True
# 1         1       1  38.0      1      0  71.2833  False  False  False
# 2         1       3  26.0      0      0   7.9250  False  False   True
# 3         1       1  35.0      1      0  53.1000  False  False   True
# 4         0       3  35.0      0      0   8.0500   True  False   True

# %%
x = full_data.drop("Survived", axis = 1)
y = full_data["Survived"]

# %%
x.shape
# Out:
# (889, 8)

# %%
y.shape
# Out:
# (889,)

# %%
from sklearn import preprocessing
pre_process = preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .20, random_state = 101)

# %%
x_train.shape
x_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare   male      Q      S
# 307       1  17.0      1      0  108.9000  False  False  False
# 229       3  24.0      3      1   25.4667  False  False   True
# 82        3  24.0      0      0    7.7875  False   True  False
# 353       3  25.0      1      0   17.8000   True  False   True
# 707       1  42.0      0      0   26.2875   True  False   True
# ..      ...   ...    ...    ...       ...    ...    ...    ...
# 576       2  34.0      0      0   13.0000  False  False   True
# 840       3  20.0      0      0    7.9250   True  False   True
# 338       3  45.0      0      0    8.0500   True  False   True
# 524       3  24.0      0      0    7.2292   True  False  False
# 865       2  42.0      0      0   13.0000  False  False   True
#
# [711 rows x 8 columns]

# %%
y_train.shape
y_train
# Out:
# 307    1
# 229    0
# 82     1
# 353    0
# 707    1
#       ..
# 576    1
# 840    0
# 338    1
# 524    0
# 865    1
# Name: Survived, Length: 711, dtype: int64

# %%
x_test.shape
x_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare   male      Q      S
# 511       3  24.0      0      0    8.0500   True  False   True
# 613       3  24.0      0      0    7.7500   True   True  False
# 615       2  24.0      1      2   65.0000  False  False   True
# 337       1  41.0      0      0  134.5000  False  False  False
# 718       3  24.0      0      0   15.5000   True   True  False
# ..      ...   ...    ...    ...       ...    ...    ...    ...
# 155       1  51.0      0      1   61.3792   True  False  False
# 450       2  36.0      1      2   27.7500   True  False   True
# 756       3  28.0      0      0    7.7958   True  False   True
# 187       1  45.0      0      0   26.5500   True  False   True
# 180       3  24.0      8      2   69.5500  False  False   True
#
# [178 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression

print("Logistics Regression")

log_reg = LogisticRegression()

log_reg.fit(x_train, y_train)
# Out:
# Logistics Regression
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred_log_reg = log_reg.predict(x_test)
print("Logistic Regression")
print("--"*30)
log_reg_accuracy = round(accuracy_score(y_test, y_pred_log_reg) * 100,2)
print("Accuracy", log_reg_accuracy, '%')
# Out:
# Logistic Regression
# ------------------------------------------------------------
# Accuracy 82.02 %

# %%
from sklearn.tree import DecisionTreeClassifier
print("Decision Tree Classifier")
Dtree = DecisionTreeClassifier()
Dtree.fit(x_train, y_train)
# Out:
# Decision Tree Classifier
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred_Dtree = Dtree.predict(x_test)
print("Decision Tree Classifier")
print("---"*20)
Dtree_accuracy = round(accuracy_score(y_test, y_pred_Dtree) * 100,2)
print("Accuracy", Dtree_accuracy, "%")
# Out:
# Decision Tree Classifier
# ------------------------------------------------------------
# Accuracy 80.34 %

# %%
from sklearn.ensemble import RandomForestClassifier
print("Random Forest Classifier")
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# Random Forest Classifier
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred_rfc = rfc.predict(x_test)
print("Random Forest Classifier")
print("--"*20)
rfc_accuracy = round(accuracy_score(y_test, y_pred_rfc) * 100,2)
print("Accuracy", rfc_accuracy, "%")
# Out:
# Random Forest Classifier
# ----------------------------------------
# Accuracy 83.15 %

# %%
from sklearn.ensemble import GradientBoostingClassifier
print("Gradient Boosting Classifier")
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
# Out:
# Gradient Boosting Classifier
# GradientBoostingClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred_gbc = gbc.predict(x_test)
print("Gradient Boosting Classifier")
print("--" * 20)
gbc_accuracy = round(accuracy_score(y_test, y_pred_gbc) * 100,2)
print("Accuracy", gbc_accuracy, "%")
# Out:
# Gradient Boosting Classifier
# ----------------------------------------
# Accuracy 84.27 %

# %%
model_scores = {
    "Logistic Regression" : 82.02,
    "Decision Tree Regressor" : 80.34, 
    "Random Forest Classifier" : 83.15, 
    "Gradient Boosting Classifer" : 84.27
}

sorted_scores = sorted(model_scores.items(), key = lambda x : x[1], reverse = True)

print("Model Rankings (Greater values are better):")
for rank, (model_name, score) in enumerate(sorted_scores, start = 1):
    print(f"{rank}. {model_name} : {score}")
# Out:
# Model Rankings (Greater values are better):
# 1. Gradient Boosting Classifer : 84.27
# 2. Random Forest Classifier : 83.15
# 3. Logistic Regression : 82.02
# 4. Decision Tree Regressor : 80.34
